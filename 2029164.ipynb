# %% [markdown]
# #  赛题链接：[常规赛：图神经网络入门节点分类](https://aistudio.baidu.com/aistudio/competition/detail/59)
#
# ## （1）赛题介绍
# 图神经网络（Graph Neural Network）是一种专门处理图结构数据的神经网络，目前被广泛应用于推荐系统、金融风控、生物计算中。图神经网络的经典问题主要有三种，包括节点分类、连接预测和图分类三种。本次比赛是图神经网络7日打卡课程的大作业，主要让同学们熟悉如何图神经网络处理节点分类问题。
#
# 在过去的一个世纪里，科学出版物的数量每12年增加近一倍，对每一种出版物的主题及领域进行自动分类已成为当下十分重要的工作。本次任务的目标是预测未知论文的主题类别，如软件工程，人工智能，语言计算和操作系统等。比赛所选35个领域标签已得到论文作者和arXiv版主确认并标记。
#
# 本次比赛选用的数据集为arXiv论文引用网络——ogbn-arixv数据集的子集。ogbn-arixv数据集由大量的学术论文组成，论文之间的引用关系形成一张巨大的有向图，每一条有向边表示一篇论文引用另一篇论文，每一个节点提供100维简单的词向量作为节点特征。在论文引用网络中，我们已对训练集对应节点做了论文类别标注处理。本次任务希望参赛者通过已有的节点类别以及论文之间的引用关系，预测未知节点的论文类别。
#
# ## （2）数据描述
# 本次赛题数据集由学术网络图构成，该图会给出每个节点的特征，以及节点与节点间关系（训练集节点的标注结果已给出）。
#
# ### 数据集简介：
# **1.学术网络图数据：**
#
# 该图包含1647958条有向边，130644个节点，参赛者报名成功后即可通过比赛数据集页面提供edges.csv以及feat.npy下载并读取数据。图上的每个节点代表一篇论文，论文从0开始编号；图上的每一条边包含两个编号，例如 3，4代表第3篇论文引用了第4篇论文。图构造可以参照AiStudio上提供的基线系统项目了解数据读取方法。
#
# **2.训练集与测试集：**
#
# 训练集的标注数据有70235条，测试集的标注数据有37311条。训练数据给定了论文编号与类别，如3，15 代表编号为3的论文类别为15。测试集数据只提供论文编号，不提供论文类别，需要参赛者预测其类别。
#
# 具体数据介绍：
#
# **1.图数据：**
#
# feat.npy为Numpy格式存储的节点特征矩阵，Shape为(130644, 100)，即130644个节点，每个节点含100维特征。其中 feat.npy可以用numpy.load(“feat.npy”)读取。edges.csv用于标记论文引用关系，为无向图，且由两列组成，没有表头。
# | 字段 | 说明 |
# | -------- | -------- |
# | 第一列 | 边的初始节点 |
# | 第二列 | 边的终止节点 |
#
# **2.训练集： train.csv**
# | 字段 | 说明 |
# | -------- | -------- |
# | nid | 训练节点在图上的Id |
# | label | 训练节点的标签（类别编号从0开始，共35个类别） |
#
# **3.测试集： test.csv**
# | 字段 | 说明 |
# | -------- | -------- |
# | nid | 测试节点在图上的Id |
#
# ## （3）相关资料
#
# （1） [飞桨PGL图学习框架](https://github.com/PaddlePaddle/PGL)
#
# 飞桨PGL图学习框架基本能够覆盖大部分的图网络应用，包括图表示学习以及图神经网络。
#
# （2） [节点分类实例分享](https://github.com/PaddlePaddle/PGL/tree/main/examples/citation_benchmark)
#
# 包含多种引用网络模型，如GCN、GAT、GCNII、APPNP等。
#
# （3）[图神经网络配套课程](https://aistudio.baidu.com/aistudio/course/introduce/1956?hmsr=PGL%E5%B8%B8%E8%A7%84%E8%B5%9B&hmpl=&hmcu=&hmkw=&hmci=)
#
# 本课程由百度飞桨7日打卡营免费提供，更多课程点击[此处](https://aistudio.baidu.com/aistudio/course)查看。
#
# （4）[UniMP模型](https://github.com/PaddlePaddle/PGL/tree/main/ogb_examples/nodeproppred/unimp)
#
# 统一消息传递模型UniMP，同时实现了节点的特征与标签传递，显著提升了模型的泛化效果。
#
# ## （4）提交内容与格式
#
# 最终提交的submission.csv 格式如下：
# | 字段 | 说明 |
# | -------- | -------- |
# | nid | 测试集节点在图上的id |
# | label | 测试集的节点类别 |
#
# **特别提示：** 提交的结果必须是类别的id，不能是概率。
#
# 提交样例：
# | nid | label |
# | -------- | -------- |
# | 2 | 34 |
# | 3 | 1 |
# | 4 | 15 |
# | … | … |
#
#
# **注意**：选手提交的csv文件的第一行为”nid,label”，顺序调转将视为无效答案。接下来每一行的两个数字依次表示测试集提供的节点id以及对应的预测论文类别，注意给出的预测类别id要属于给定范围值且必须是整数。提交的数据行数要与test.csv一致。

# %% [markdown]
# # 运行方式
# 本次基线基于飞桨PaddlePaddle 1.8.4版本，若本地运行则可能需要额外安装pgl、easydict、pandas等模块。
#
# ## 1.本地运行
# 下载左侧文件夹中的所有py文件（包括build_model.py, model.py）,以及work目录，然后在右上角“文件”->“导出Notebook到py”，这样可以保证代码是最新版本），执行导出的py文件即可。完成后下载submission.csv提交结果即可。
#
# ## 2.AI Studio (Notebook)运行
# 依次运行下方的cell，完成后下载submission.csv提交结果即可。**若运行时修改了cell，推荐在右上角重启执行器后再以此运行，避免因内存未清空而产生报错**。 Tips：若修改了左侧文件夹中数据，也需要重启执行器后才会加载新文件。

# %% [markdown]
# # 代码整体逻辑
#
# 1. 读取提供的数据集，包含构图以及读取节点特征（用户可自己改动边的构造方式）
#
# 2. 配置化生成模型，用户也可以根据教程进行图神经网络的实现。
#
# 3. 开始训练
#
# 4. 执行预测并产生结果文件
#
# ## （1）环境配置
#
# 该项目依赖飞桨paddlepaddle==1.8.4, 以及pgl==1.2.0。请按照版本号下载对应版本就可运行。

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# !mkdir /home/aistudio/external-libraries
# !pip install xgboost==1.1.0 pgl==1.2.0 easydict -t /home/aistudio/external-libraries
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple/
# Collecting xgboost==1.1.0
#   Downloading https://mirror.baidu.com/pypi/packages/75/6c/fb30ff1703846db8e8e511399e41123ac968dc29171f04e9f0b2585e40c9/xgboost-1.1.0-py3-none-manylinux2010_x86_64.whl (127.6MB)
#      |████████████████████████████████| 127.6MB 9.7MB/s eta 0:00:01     |█████▍                          | 21.6MB 9.2MB/s eta 0:00:12
# Collecting pgl==1.2.0
#   Downloading https://mirror.baidu.com/pypi/packages/35/fa/2290e78914d34d4e4480d7982b8f4d0c58a7e53535113a668a9d75d5c3b6/pgl-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (7.9MB)
#      |████████████████████████████████| 7.9MB 13.7MB/s eta 0:00:01
# Collecting easydict
#   Downloading https://mirror.baidu.com/pypi/packages/4c/c5/5757886c4f538c1b3f95f6745499a24bffa389a805dee92d093e2d9ba7db/easydict-1.9.tar.gz
# Collecting scipy (from xgboost==1.1.0)
#   Downloading https://mirror.baidu.com/pypi/packages/7d/e8/43ffca541d2f208d516296950b25fe1084b35c2881f4d444c1346ca75815/scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4MB)
#      |████████████████████████████████| 27.4MB 8.2MB/s eta 0:00:012     |██████████████▎                 | 12.3MB 8.8MB/s eta 0:00:02
# Collecting numpy (from xgboost==1.1.0)
#   Downloading https://mirror.baidu.com/pypi/packages/a5/42/560d269f604d3e186a57c21a363e77e199358d054884e61b73e405dd217c/numpy-1.20.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.3MB)
#      |████████████████████████████████| 15.3MB 9.0MB/s eta 0:00:011
# Collecting cython>=0.25.2 (from pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/0c/15/cca3ac44776df9ee27286941315dd8b14a598e8d80970200d05f720b9274/Cython-0.29.23-cp37-cp37m-manylinux1_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 13.6MB/s eta 0:00:01
# Collecting redis-py-cluster (from pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/b2/96/153bbcf5dee29b52b2674e77a87ce864d381f72151737317529b7de4f337/redis_py_cluster-2.1.3-py2.py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 40.9MB/s eta 0:00:01
# Collecting visualdl>=2.0.0b; python_version >= "3" (from pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/31/99/f5f50d035006b0d9304700facd9e1c843af8e02569474996d1b6a79529f6/visualdl-2.2.0-py3-none-any.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 26.3MB/s eta 0:00:01
# Collecting redis<4.0.0,>=3.0.0 (from redis-py-cluster->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 15.0MB/s eta 0:00:01
# Collecting protobuf>=3.11.0 (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/48/72/05ec80a16a85d9c0e69020ab731b1dafdf2fee591b30811c6b63ec447afe/protobuf-3.17.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 15.8MB/s eta 0:00:01
# Collecting flake8>=3.7.9 (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/fc/80/35a0716e5d5101e643404dabd20f07f5528a21f3ef4032d31a49c913237b/flake8-3.9.2-py2.py3-none-any.whl (73kB)
#      |████████████████████████████████| 81kB 18.0MB/s eta 0:00:01
# Collecting Pillow>=7.0.0 (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/33/34/542152297dcc6c47a9dcb0685eac6d652d878ed3cea83bf2b23cb988e857/Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 16.4MB/s eta 0:00:01
# Collecting pre-commit (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/b2/38/3e5475cbd6921cd8208a06c113384a88bb19ce0cda1155f33d4f19183de1/pre_commit-2.13.0-py2.py3-none-any.whl (190kB)
#      |████████████████████████████████| 194kB 19.4MB/s eta 0:00:01
# Collecting pandas (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/51/51/48f3fc47c4e2144da2806dfb6629c4dd1fa3d5a143f9652b141e979a8ca9/pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9MB)
#      |████████████████████████████████| 9.9MB 27.5MB/s eta 0:00:01
# Collecting flask>=1.1.1 (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/54/4f/1b294c1a4ab7b2ad5ca5fc4a9a65a22ef1ac48be126289d97668852d4ab3/Flask-2.0.1-py3-none-any.whl (94kB)
#      |████████████████████████████████| 102kB 27.2MB/s ta 0:00:01
# Collecting Flask-Babel>=1.0.0 (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/ab/3e/02331179ffab8b79e0383606a028b6a60fb1b4419b84935edd43223406a0/Flask_Babel-2.0.0-py3-none-any.whl
# Collecting shellcheck-py (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/77/c9/6f84db444de69e1bdbfd168ae6f3d5af72107c16cd9db3c0a1f8e41204d1/shellcheck_py-0.7.2.1-py2.py3-none-manylinux1_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 15.7MB/s eta 0:00:01
# Collecting matplotlib (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/24/33/5568d443ba438d95d4db635dd69958056f087e57e1026bee56f959d53f9d/matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3MB)
#      |████████████████████████████████| 10.3MB 14.5MB/s eta 0:00:01
# Collecting requests (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/29/c1/24814557f1d22c56d50280771a17307e6bf87b70727d975fd6b2ce6b014a/requests-2.25.1-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 19.1MB/s eta 0:00:01
# Collecting bce-python-sdk (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/09/c2/6336452f3cd267c525e1142d6f20f70dd0abc4504105d8a04e79df16b54a/bce_python_sdk-0.8.60-py3-none-any.whl (197kB)
#      |████████████████████████████████| 204kB 20.4MB/s eta 0:00:01
# Collecting six>=1.14.0 (from visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8" (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/0b/05/9215a7ea1110477bd85375941327857c6a78beb0fbb9d1c2652e28fd04a0/importlib_metadata-4.4.0-py3-none-any.whl
# Collecting mccabe<0.7.0,>=0.6.0 (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/87/89/479dc97e18549e21354893e4ee4ef36db1d237534982482c3681ee6e7b57/mccabe-0.6.1-py2.py3-none-any.whl
# Collecting pycodestyle<2.8.0,>=2.7.0 (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/de/cc/227251b1471f129bc35e966bb0fceb005969023926d744139642d847b7ae/pycodestyle-2.7.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 22.6MB/s eta 0:00:01
# Collecting pyflakes<2.4.0,>=2.3.0 (from flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/6c/11/2a745612f1d3cbbd9c69ba14b1b43a35a2f5c3c81cd0124508c52c64307f/pyflakes-2.3.1-py2.py3-none-any.whl (68kB)
#      |████████████████████████████████| 71kB 11.5MB/s eta 0:00:01
# Collecting pyyaml>=5.1 (from pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636kB)
#      |████████████████████████████████| 645kB 14.3MB/s eta 0:00:01
# Collecting cfgv>=2.0.0 (from pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/49/54/83bf9b6ba673bf7d5ebe3846a5f6d3a53925cfd331aa29ec6b5b9c42a850/cfgv-3.3.0-py2.py3-none-any.whl
# Collecting toml (from pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl
# Collecting nodeenv>=0.11.1 (from pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/54/73/56c89b343befb9c63e8117294d265458f0ff726fa2abcdc6bb5ec5e66a1a/nodeenv-1.6.0-py2.py3-none-any.whl
# Collecting identify>=1.0.0 (from pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/d5/e8/8cda16c3288ebe5cad40cbb84590caf72d1aec1d4fa2e61bed4ee306c532/identify-2.2.7-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 16.1MB/s ta 0:00:01
# Collecting virtualenv>=20.0.8 (from pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/03/08/f819421002e85a71d58368f7bffbe0b1921325e0e8ca7857cb5fb0e1f7c1/virtualenv-20.4.7-py2.py3-none-any.whl (7.2MB)
#      |████████████████████████████████| 7.2MB 27.7MB/s eta 0:00:01
# Collecting pytz>=2017.3 (from pandas->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/70/94/784178ca5dd892a98f113cdd923372024dc04b8d40abe77ca76b5fb90ca6/pytz-2021.1-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 15.2MB/s eta 0:00:01
# Collecting python-dateutil>=2.7.3 (from pandas->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
#      |████████████████████████████████| 235kB 50.8MB/s eta 0:00:01
# Collecting Jinja2>=3.0 (from flask>=1.1.1->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/80/21/ae597efc7ed8caaa43fb35062288baaf99a7d43ff0cf66452ddf47604ee6/Jinja2-3.0.1-py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 15.6MB/s eta 0:00:01
# Collecting Werkzeug>=2.0 (from flask>=1.1.1->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/bd/24/11c3ea5a7e866bf2d97f0501d0b4b1c9bbeade102bb4b588f0d2919a5212/Werkzeug-2.0.1-py3-none-any.whl (288kB)
#      |████████████████████████████████| 296kB 23.6MB/s eta 0:00:01
# Collecting itsdangerous>=2.0 (from flask>=1.1.1->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/9c/96/26f935afba9cd6140216da5add223a0c465b99d0f112b68a4ca426441019/itsdangerous-2.0.1-py3-none-any.whl
# Collecting click>=7.1.2 (from flask>=1.1.1->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/76/0a/b6c5f311e32aeb3b406e03c079ade51e905ea630fc19d1262a46249c1c86/click-8.0.1-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 25.1MB/s ta 0:00:01
# Collecting Babel>=2.3 (from Flask-Babel>=1.0.0->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/aa/96/4ba93c5f40459dc850d25f9ba93f869a623e77aaecc7a9344e19c01942cf/Babel-2.9.1-py2.py3-none-any.whl (8.8MB)
#      |████████████████████████████████| 8.8MB 13.3MB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/d2/46/231de802ade4225b76b96cffe419cf3ce52bbe92e3b092cf12db7d11c207/kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 49.4MB/s eta 0:00:01
# Collecting pyparsing>=2.2.1 (from matplotlib->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 13.2MB/s eta 0:00:01
# Collecting chardet<5,>=3.0.2 (from requests->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/19/c7/fa589626997dd07bd87d9269342ccb74b1720384a4d739a1872bd84fbe68/chardet-4.0.0-py2.py3-none-any.whl (178kB)
#      |████████████████████████████████| 184kB 23.1MB/s eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1 (from requests->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/0c/cd/1e2ec680ec7b09846dc6e605f5a7709dfb9d7128e51a026e7154e18a234e/urllib3-1.26.5-py2.py3-none-any.whl (138kB)
#      |████████████████████████████████| 143kB 61.1MB/s eta 0:00:01
# Collecting idna<3,>=2.5 (from requests->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 17.9MB/s eta 0:00:01
# Collecting certifi>=2017.4.17 (from requests->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/05/1b/0a0dece0e8aa492a6ec9e4ad2fe366b511558cdc73fd3abc82ba7348e875/certifi-2021.5.30-py2.py3-none-any.whl (145kB)
#      |████████████████████████████████| 153kB 59.9MB/s eta 0:00:01
# Collecting future>=0.6.0 (from bce-python-sdk->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 13.9MB/s eta 0:00:01
# Collecting pycryptodome>=3.8.0 (from bce-python-sdk->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/ad/16/9627ab0493894a11c68e46000dbcc82f578c8ff06bc2980dcd016aea9bd3/pycryptodome-3.10.1-cp35-abi3-manylinux2010_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 19.1MB/s eta 0:00:01
# Collecting typing-extensions>=3.6.4; python_version < "3.8" (from importlib-metadata; python_version < "3.8"->flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/2e/35/6c4fff5ab443b57116cb1aad46421fb719bed2825664e8fe77d66d99bcbc/typing_extensions-3.10.0.0-py3-none-any.whl
# Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->flake8>=3.7.9->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/0f/8c/715c54e9e34c0c4820f616a913a7de3337d0cd79074dd1bed4dd840f16ae/zipp-3.4.1-py3-none-any.whl
# Collecting filelock<4,>=3.0.0 (from virtualenv>=20.0.8->pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/93/83/71a2ee6158bb9f39a90c0dea1637f81d5eef866e188e1971a1b1ab01a35a/filelock-3.0.12-py3-none-any.whl
# Collecting distlib<1,>=0.3.1 (from virtualenv>=20.0.8->pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/87/26/f6a23dd3e578132cf924e0dd5d4e055af0cd4ab43e2a9f10b7568bfb39d9/distlib-0.3.2-py2.py3-none-any.whl (338kB)
#      |████████████████████████████████| 348kB 20.0MB/s eta 0:00:01
# Collecting appdirs<2,>=1.4.3 (from virtualenv>=20.0.8->pre-commit->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting MarkupSafe>=2.0 (from Jinja2>=3.0->flask>=1.1.1->visualdl>=2.0.0b; python_version >= "3"->pgl==1.2.0)
#   Downloading https://mirror.baidu.com/pypi/packages/ad/cd/650b1be2a81674939ef962b1f1b956e4a84116d69708c842667445e95408/MarkupSafe-2.0.1-cp37-cp37m-manylinux2010_x86_64.whl
# Building wheels for collected packages: easydict, future
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-cp37-none-any.whl size=6350 sha256=e6b9f52fc712ad8e5feffbc6910f5142ae51605f345173f649c174b56a1817c0
#   Stored in directory: /home/aistudio/.cache/pip/wheels/35/8b/38/7327c27cd3d4590ffa75b98030bd3828e68b8bb3d599573163
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp37-none-any.whl size=491057 sha256=6b67bbd4f2bede93b5ed5b0e8847aed6462ea191cdaf1235b3126956c8e6f6bd
#   Stored in directory: /home/aistudio/.cache/pip/wheels/f5/70/cc/574eabb9745e81a45d873844595825ca74d0083b5f9f044737
# Successfully built easydict future
# ERROR: blackhole 0.3.2 has requirement pandas<=1.1.5,>=0.24.0, but you'll have pandas 1.2.4 which is incompatible.
# Installing collected packages: numpy, scipy, xgboost, cython, redis, redis-py-cluster, six, protobuf, typing-extensions, zipp, importlib-metadata, mccabe, pycodestyle, pyflakes, flake8, Pillow, pyyaml, cfgv, toml, nodeenv, identify, filelock, distlib, appdirs, virtualenv, pre-commit, pytz, python-dateutil, pandas, MarkupSafe, Jinja2, Werkzeug, itsdangerous, click, flask, Babel, Flask-Babel, shellcheck-py, cycler, kiwisolver, pyparsing, matplotlib, chardet, urllib3, idna, certifi, requests, future, pycryptodome, bce-python-sdk, visualdl, pgl, easydict
# Successfully installed Babel-2.9.1 Flask-Babel-2.0.0 Jinja2-3.0.1 MarkupSafe-2.0.1 Pillow-8.2.0 Werkzeug-2.0.1 appdirs-1.4.4 bce-python-sdk-0.8.60 certifi-2021.5.30 cfgv-3.3.0 chardet-4.0.0 click-8.0.1 cycler-0.10.0 cython-0.29.23 distlib-0.3.2 easydict-1.9 filelock-3.0.12 flake8-3.9.2 flask-2.0.1 future-0.18.2 identify-2.2.7 idna-2.10 importlib-metadata-4.4.0 itsdangerous-2.0.1 kiwisolver-1.3.1 matplotlib-3.4.2 mccabe-0.6.1 nodeenv-1.6.0 numpy-1.20.3 pandas-1.2.4 pgl-1.2.0 pre-commit-2.13.0 protobuf-3.17.2 pycodestyle-2.7.0 pycryptodome-3.10.1 pyflakes-2.3.1 pyparsing-2.4.7 python-dateutil-2.8.1 pytz-2021.1 pyyaml-5.4.1 redis-3.5.3 redis-py-cluster-2.1.3 requests-2.25.1 scipy-1.6.3 shellcheck-py-0.7.2.1 six-1.16.0 toml-0.10.2 typing-extensions-3.10.0.0 urllib3-1.26.5 virtualenv-20.4.7 visualdl-2.2.0 xgboost-1.1.0 zipp-3.4.1

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可: 
import sys 
sys.path.append('/home/aistudio/external-libraries')

# %%
import pgl
import paddle.fluid as fluid
import paddle.fluid.layers
import numpy as np
import time
import pandas as pd
from pgl.utils import paddle_helper
from pgl import message_passing
import math

# %%
from easydict import EasyDict as edict

config = {
    "model_name": "res_unimp_large",
    "num_layers": 3,
    "hidden_size": 128,
    "heads": 2,
    "learning_rate": 0.001,
    "dropout": 0.33,
    "weight_decay": 0.0005,
    "edge_dropout": 0.32,
    "use_label_e": True
}


config = edict(config)

# %% [markdown]
# ## （3）数据加载模块
#
# 这里主要是用于读取数据集，包括读取图数据构图，以及训练集的划分。

# %%
from collections import namedtuple

Dataset = namedtuple("Dataset", 
               ["graph", "num_classes", "train_index",
                "train_label", "valid_index", "valid_label", "test_index"])

def load_edges(num_nodes, self_loop=True, add_inverse_edge=True):
    # 从数据中读取边
    edges = pd.read_csv("work/edges.csv", header=None, names=["src", "dst"]).values

    if add_inverse_edge:
        edges = np.vstack([edges, edges[:, ::-1]])

    if self_loop:
        src = np.arange(0, num_nodes)
        dst = np.arange(0, num_nodes)
        self_loop = np.vstack([src, dst]).T
        edges = np.vstack([edges, self_loop])
    
    return edges

def load():
    # 从数据中读取点特征和边，以及数据划分
    node_feat = np.load("work/feat.npy")
    num_nodes = node_feat.shape[0]
    edges = load_edges(num_nodes=num_nodes, self_loop=True, add_inverse_edge=True)
    graph = pgl.graph.Graph(num_nodes=num_nodes, edges=edges, node_feat={"feat": node_feat})
    
    indegree = graph.indegree()
    norm = np.maximum(indegree.astype("float32"), 1)
    norm = np.power(norm, -0.5)
    graph.node_feat["norm"] = np.expand_dims(norm, -1)
    
    df = pd.read_csv("work/train.csv")
    node_index = df["nid"].values
    node_label = df["label"].values
    train_part = int(len(node_index) * 0.8)
    train_index = node_index[:train_part]
    train_label = node_label[:train_part]
    valid_index = node_index[train_part:]
    valid_label = node_label[train_part:]
    test_index = pd.read_csv("work/test.csv")["nid"].values
    dataset = Dataset(graph=graph, 
                    train_label=train_label,
                    train_index=train_index,
                    valid_index=valid_index,
                    valid_label=valid_label,
                    test_index=test_index, num_classes=35)
    return dataset

# %%
dataset = load()

train_index = dataset.train_index
train_label = np.reshape(dataset.train_label, [-1 , 1])
train_index = np.expand_dims(train_index, -1)

val_index = dataset.valid_index
val_label = np.reshape(dataset.valid_label, [-1, 1])
val_index = np.expand_dims(val_index, -1)

test_index = dataset.test_index
test_index = np.expand_dims(test_index, -1)
test_label = np.zeros((len(test_index), 1), dtype="int64")

# %% [markdown]
# ## （4）组网模块
#
# 这里是组网模块，目前已经提供了一些预定义的模型，包括**GCN**, **GAT**, **APPNP**等。可以通过简单的配置，设定模型的层数，hidden_size等。你也可以深入到model.py里面，去奇思妙想，写自己的图神经网络。

# %%
import pgl
import model
import paddle.fluid as fluid
import numpy as np
import time
from build_model import build_model

# 使用CPU
#place = fluid.CPUPlace()

# # 使用GPU
place = fluid.CUDAPlace(0)

train_program = fluid.default_main_program()
startup_program = fluid.default_startup_program()
with fluid.program_guard(train_program, startup_program):
    with fluid.unique_name.guard():
        gw, loss, acc, pred = build_model(dataset,
                            config=config,
                            phase="train",
                            main_prog=train_program)

test_program = fluid.Program()
with fluid.program_guard(test_program, startup_program):
    with fluid.unique_name.guard():
        _gw, v_loss, v_acc, v_pred = build_model(dataset,
            config=config,
            phase="test",
            main_prog=test_program)


test_program = test_program.clone(for_test=True)

exe = fluid.Executor(place)

# %% [markdown]
# ## （5）开始训练过程
#
# 图神经网络采用FullBatch的训练方式，每一步训练就会把所有整张图训练样本全部训练一遍。

# %%
import os
use_label_e = True
label_rate = 0.5
epoch = 2000
exe.run(startup_program)
max_val_acc = 0

# 这里可以恢复训练
pretrained = False
if pretrained:
    def name_filter(var):
        res = var.name in os.listdir('./output')
        return res
    fluid.io.load_vars(exe, './output',predicate=name_filter)

earlystop = 0
# 将图数据变成 feed_dict 用于传入Paddle Excecutor
feed_dict = gw.to_feed(dataset.graph)
for epoch in range(epoch):
    # Full Batch 训练
    # 设定图上面那些节点要获取
    # node_index: 训练节点的nid    
    # node_label: 训练节点对应的标签
    
    if use_label_e:
        train_idx_temp = np.array(train_index, dtype="int64")
        train_lab_temp = np.array(train_label, dtype="int64")
        state = np.random.get_state()
        np.random.shuffle(train_idx_temp)
        np.random.set_state(state)
        np.random.shuffle(train_lab_temp)

        label_idx=train_idx_temp[:int(label_rate*len(train_idx_temp))]
        unlabel_idx=train_idx_temp[int(label_rate*len(train_idx_temp)):]
        label=train_lab_temp[:int(label_rate*len(train_idx_temp))]
        unlabel=train_lab_temp[int(label_rate*len(train_idx_temp)):]

        feed_dict["node_index"] = unlabel_idx
        feed_dict["node_label"] = unlabel
        feed_dict['label_idx']= label_idx
        feed_dict['label']= label
    else:
        feed_dict["node_label"] = np.array(train_label, dtype="int64")
        feed_dict["node_index"] = np.array(train_index, dtype="int64")
        

    train_loss, train_acc = exe.run(train_program,
                                feed=feed_dict,
                                fetch_list=[loss, acc],
                                return_numpy=True)

    # Full Batch 验证
    # 设定图上面那些节点要获取
    # node_index: 训练节点的nid    
    # node_label: 训练节点对应的标签
    feed_dict["node_index"] = np.array(val_index, dtype="int64")
    feed_dict["node_label"] = np.array(val_label, dtype="int64")
    if use_label_e:
        feed_dict['label_idx'] = np.array(train_index, dtype="int64")
        feed_dict['label'] = np.array(train_label, dtype="int64")
    val_loss, val_acc = exe.run(test_program,
                            feed=feed_dict,
                            fetch_list=[v_loss, v_acc],
                            return_numpy=True)
    print("Epoch", epoch, "Train Acc", train_acc[0], "Valid Acc", val_acc[0])
    if val_acc[0] > max_val_acc:
        max_val_acc = val_acc[0]
        fluid.io.save_persistables(exe, './output', train_program)
    if train_acc[0] > val_acc[0]:
        earlystop += 1
        if earlystop == 40:
            break
    else:
        earlystop = 0
# Out:
# Epoch 1999 Train Acc 0.7537196 Valid Acc 0.76080304

# %% [markdown]
# ## （6）对测试集进行预测
#
# 训练完成后，我们对测试集进行预测。预测的时候，由于不知道测试集合的标签，我们随意给一些测试label。最终我们获得测试数据的预测结果。

# %%
feed_dict["node_index"] = np.array(test_index, dtype="int64")
feed_dict["node_label"] = np.array(test_label, dtype="int64") #假标签

if use_label_e:
    feed_dict['label_idx'] = np.array(train_index, dtype="int64")
    feed_dict['label'] = np.array(train_label, dtype="int64")

test_prediction = exe.run(test_program,
                            feed=feed_dict,
                            fetch_list=[v_pred],
                            return_numpy=True)[0]

# %% [markdown]
# ## （7）生成提交文件
#
# 最后一步，我们可以使用pandas轻松生成提交文件，最后下载 submission.csv 提交就好了。

# %%
submission = pd.DataFrame(data={
                            "nid": test_index.reshape(-1),
                            "label": test_prediction.reshape(-1)
                        })
submission.to_csv("submission.csv", index=False)

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
